# %%
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt
import datetime as dt
import requests
import json
from flask import jsonify
from pprint import pprint
from  jsonmerge import merge
import pymongo
from pymongo import MongoClient

# %%
import numpy as np
import pandas as pd
import datetime as dt

# %%
import requests

queries = ["hotel", "restaurant", "shopping", "museum", "grocery store"]
hotels = []
restaurants = []
shopping = []
museums = []
groceries = []
for i in range(5):
    print(queries[i])
    url = "https://api.foursquare.com/v3/places/nearby?ll=40.7128%2C-74.0060&hacc=10000&query=" + queries[i] + "&limit=50"

    headers = {
        "Accept": "application/json",
        "Authorization": "fsq39JU8BJKumYvy8NsgYZPmgv/XJEH17AoYu8gSSNy6v1I="
    }
    response = requests.request("GET", url, headers=headers)
    
    data_json = response.json()
    data = data_json["results"]
    for x in data:
        hotel_dict = {}
        restaurant_dict = {}
        shopping_dict = {}
        museums_dict = {}
        groceries_dict = {}
        #Collect data for each category and store it corresponding list
        try:
            if i == 0:
                name = x["name"]
                location = [x["geocodes"]["main"]["latitude"],x["geocodes"]["main"]["longitude"]]
                distance = x["distance"]
                address = x["location"]["address"]+' '+x["location"]["locality"]+' '+x["location"]["region"]+' '+ x["location"]["postcode"]
                ctg = x["categories"][0]["name"]
                hotel_dict = {"name":name, "location":location,"address":address,"distance":distance,"category":ctg}
                hotels.append(hotel_dict)

            elif i == 1:
                name = x["name"]
                location = [x["geocodes"]["main"]["latitude"],x["geocodes"]["main"]["longitude"]]
                distance = x["distance"]
                address = x["location"]["address"]+' '+x["location"]["locality"]+' '+x["location"]["region"]+' '+ x["location"]["postcode"]
                ctg = x["categories"][0]["name"]
                restaurant_dict = {"name":name, "location":location,"address":address,"distance":distance,"category":ctg}
                restaurants.append(restaurant_dict)

            elif i == 2:
                name = x["name"]
                location = [x["geocodes"]["main"]["latitude"],x["geocodes"]["main"]["longitude"]]
                distance = x["distance"]
                address = x["location"]["address"]+' '+ x["location"]["locality"]+' '+ x["location"]["region"]+' '+ x["location"]["postcode"]
                #ctg = x["categories"][0]["name"]
                shopping_dict = {"name":name, "location":location,"address":address,"distance":distance}
                shopping.append(shopping_dict)
                
            elif i == 3:
                name = x["name"]
                location = [x["geocodes"]["main"]["latitude"],x["geocodes"]["main"]["longitude"]]
                distance = x["distance"]
                address = x["location"]["address"]+' '+x["location"]["locality"]+' '+x["location"]["region"]+' '+x["location"]["postcode"]
                ctg = x["categories"][0]["name"]
                museums_dict = {"name":name, "location":location,"address":address,"distance":distance,"category":ctg}
                museums.append(museums_dict)
                
            elif i == 4:
                name = x["name"]
                location = [x["geocodes"]["main"]["latitude"],x["geocodes"]["main"]["longitude"]]
                distance = x["distance"]
                address = x["location"]["address"]+' '+x["location"]["locality"]+' '+x["location"]["region"]+' '+x["location"]["postcode"]
                ctg = x["categories"][0]["name"]
                groceries_dict = {"name":name, "location":location,"address":address,"distance":distance,"category":ctg}
                groceries.append(groceries_dict)
            else:
                pass
        except KeyError:
            print("Something is squeeky!")
            
    
with open('hotels_data.json', 'w') as file:
   json.dump(hotels, file)
with open('restaurants_data.json', 'w') as file:
   json.dump(restaurants, file)
with open('shopping_data.json', 'w') as file:
   json.dump(shopping, file)
with open('museums_data.json', 'w') as file:
   json.dump(museums, file)
with open('groceries_data.json', 'w') as file:
   json.dump(groceries, file)
# Out:
# hotel
# restaurant
# shopping
# Something is squeeky!
# museum
# grocery store

# %%
pprint(groceries)
# Out:
# [{'address': '13B Market St New York NY 10002',
#   'category': 'Grocery Store / Supermarket',
#   'distance': 970,
#   'location': [40.713268, -73.994498],
#   'name': 'Zhou Hui Grocery Store'},
#  {'address': '329 Grand St New York NY 10002',
#   'category': 'Grocery Store / Supermarket',
#   'distance': 1397,
#   'location': [40.717195023841796, -73.99046036835232],
#   'name': 'Teng Fei Grocery Store'},
#  {'address': '47 Pitt St New York NY 10002',
#   'category': 'Deli',
#   'distance': 2139,
#   'location': [40.718983695292096, -73.9819436633251],
#   'name': '47 Pitt Grocery'},
#  {'address': '176 Underhill Ave Brooklyn NY 11238',
#   'category': 'Convenience Store',
#   'distance': 5342,
#   'location': [40.67511775039857, -73.96661410496867],
#   'name': 'Espinal Grocery'},
#  {'address': '483 Evergreen Ave Brooklyn NY 11221',
#   'category': 'Grocery Store / Supermarket',
#   'distance': 7874,
#   'location': [40.691340000000004, -73.916919],
#   'name': 'Madison Grocery Store'},
#  {'address': '322 Dekalb Ave Brooklyn NY 11205',
#   'category': 'Grocery Store / Supermarket',
#   'distance': 4277,
#   'location': [40.68962097167969, -73.96546936035156],
#   'name': 'Grocery store'},
#  {'address': '386 Chauncey St Brooklyn NY 11233',
#   'category': 'Grocery Store / Supermarket',
#   'distance': 8277,
#   'location': [40.681651, -73.916752],
#   'name': 'M & M S Grocery Store'},
#  {'address': '588 Marcy Ave Brooklyn NY 11206',
#   'category': 'Grocery Store / Supermarket',
#   'distance': 5198,
#   'location': [40.69449234008789, -73.94921112060547],
#   'name': 'Grocery store'},
#  {'address': '26 Canal St New York NY 10002',
#   'category': 'Grocery Store / Supermarket',
#   'distance': 1325,
#   'location': [40.714297377585225, -73.99038791656494],
#   'name': 'Day Light Grocery Store'},
#  {'address': '407 Keap St Brooklyn NY 11211',
#   'category': 'Convenience Store',
#   'distance': 4412,
#   'location': [40.71095720530854, -73.95367744934147],
#   'name': 'Divino Nino Grocery Store'},
#  {'address': '301 Grand St New York NY 10002',
#   'category': 'Flower Store',
#   'distance': 1299,
#   'location': [40.71741, -73.991824],
#   'name': 'W&W Grocery Store'},
#  {'address': '337 Bleecker St New York NY 10014',
#   'category': 'Miscellaneous Store',
#   'distance': 2327,
#   'location': [40.73370361328125, -74.00428771972656],
#   'name': 'Etc. Grocery Store'},
#  {'address': '486 Dean St Brooklyn NY 11217',
#   'category': 'Deli',
#   'distance': 4395,
#   'location': [40.681434629382935, -73.97422044674367],
#   'name': 'Dubai Grocery Store'},
#  {'address': '75 Mulberry St New York NY 10013',
#   'category': 'Grocery Store / Supermarket',
#   'distance': 689,
#   'location': [40.71628362630968, -73.99922579526901],
#   'name': 'Sun Vin Grocery Store'},
#  {'address': '15 Stanton St New York NY 10002',
#   'category': 'Grocery Store / Supermarket',
#   'distance': 1610,
#   'location': [40.72274919, -73.992102],
#   'name': 'Tavarez Deli Grocery Store'},
#  {'address': '618 8th Ave New York NY 10018',
#   'category': 'Convenience Store',
#   'distance': 4941,
#   'location': [40.75568771362305, -73.99050903320312],
#   'name': 'Corner News & Grocery'},
#  {'address': '105 Central Ave Brooklyn NY 11206',
#   'category': 'Grocery Store / Supermarket',
#   'distance': 6581,
#   'location': [40.70041124588944, -73.92960139410951],
#   'name': 'Los Primos Grocery'},
#  {'address': '45 Congress St Jersey City NJ 07307',
#   'category': 'Grocery Store / Supermarket',
#   'distance': 5073,
#   'location': [40.749298, -74.042198],
#   'name': "Lee's Liquor & Grocery Store"},
#  {'address': '29 Kingsland Ave Brooklyn NY 11211',
#   'category': 'Restaurant',
#   'distance': 5546,
#   'location': [40.716957092285156, -73.94038391113281],
#   'name': 'Eridnania Grocery Store'},
#  {'address': '1521 Fulton St Brooklyn NY 11216',
#   'category': 'Deli',
#   'distance': 6603,
#   'location': [40.68030219048167, -73.94038793217769],
#   'name': 'Seven & One Grocery Store'},
#  {'address': '1565 Fulton St Brooklyn NY 11216',
#   'category': 'Grocery Store / Supermarket',
#   'distance': 6746,
#   'location': [40.68000030517578, -73.93861389160156],
#   'name': 'Kristal Grocery Store'},
#  {'address': '686 Halsey St Brooklyn NY 11233',
#   'category': 'Deli',
#   'distance': 7525,
#   'location': [40.68399759174267, -73.92516110863632],
#   'name': 'Halsey grocery store'},
#  {'address': '1218 Myrtle Ave Brooklyn NY 11221',
#   'category': 'Grocery Store / Supermarket',
#   'distance': 6671,
#   'location': [40.697447, -73.92943299999999],
#   'name': 'Los Nietos Grocery Store'},
#  {'address': '99 Schenectady Ave Brooklyn NY 11213',
#   'category': 'Deli',
#   'distance': 7393,
#   'location': [40.675785999999995, -73.93308],
#   'name': 'Ab Grocery'},
#  {'address': '274 S 2nd St Brooklyn NY 11211',
#   'category': 'Grocery Store / Supermarket',
#   'distance': 4125,
#   'location': [40.711193, -73.957074],
#   'name': 'Santos Grocery Store'},
#  {'address': '790 Nostrand Ave Brooklyn NY 11216',
#   'category': 'Deli',
#   'distance': 6429,
#   'location': [40.671815693653016, -73.95213246282994],
#   'name': 'Lealy Super Deli Grocery Store'},
#  {'address': '760 Nostrand Ave Brooklyn NY 11216',
#   'category': 'Department Store',
#   'distance': 6457,
#   'location': [40.672725, -73.950506],
#   'name': 'Tasmia Discount Store'},
#  {'address': '268 Duncan Ave Jersey City NJ 07306',
#   'category': 'Grocery Store / Supermarket',
#   'distance': 6549,
#   'location': [40.728809999999996, -74.080838],
#   'name': 'Martin Grocery'},
#  {'address': '1546 Fulton St Brooklyn NY 11216',
#   'category': 'Butcher',
#   'distance': 6735,
#   'location': [40.679646999999996, -73.939071],
#   'name': 'FNL Meat & Poultry Grocery Store'},
#  {'address': '876 Nostrand Ave Brooklyn NY 11225',
#   'category': 'Grocery Store / Supermarket',
#   'distance': 6789,
#   'location': [40.668208, -73.950916],
#   'name': 'Unity Grocery'},
#  {'address': '4216 5th Ave Brooklyn NY 11232',
#   'category': 'Deli',
#   'distance': 7043,
#   'location': [40.6494140625, -74.00619506835938],
#   'name': 'Juquilita Grocery Store'},
#  {'address': 'Brooklyn ave Brooklyn NY 11216',
#   'category': 'Deli',
#   'distance': 7716,
#   'location': [40.660280269241916, -73.94609249490384],
#   'name': 'Nuñez Grocery Store'},
#  {'address': '1223 Church Ave Brooklyn NY 11218',
#   'category': 'Grocery Store / Supermarket',
#   'distance': 7904,
#   'location': [40.647856, -73.967727],
#   'name': 'Pimentel Grocery Store'},
#  {'address': '313 Wilson Ave New York NY 11237',
#   'category': 'Grocery Store / Supermarket',
#   'distance': 7576,
#   'location': [40.696777, -73.918579],
#   'name': 'Acosta Grocery Store'},
#  {'address': '5101 6th Ave Brooklyn NY 11220',
#   'category': 'Retail',
#   'distance': 7842,
#   'location': [40.642234802246094, -74.00732421875],
#   'name': 'Kang Mei Qin Grocery Store'},
#  {'address': '4809 8th Ave Brooklyn NY 11220',
#   'category': 'Grocery Store / Supermarket',
#   'distance': 7892,
#   'location': [40.64182662963867, -74.0025634765625],
#   'name': 'J & Y Grocery'},
#  {'address': '5713 4th Ave Brooklyn NY 11220',
#   'category': 'Deli',
#   'distance': 7912,
#   'location': [40.64205551147461, -74.01667022705078],
#   'name': 'Juquilita Grocery Store'},
#  {'address': '1201 Church Ave New York NY 11218',
#   'category': 'Grocery Store / Supermarket',
#   'distance': 7920,
#   'location': [40.6475, -73.968339],
#   'name': 'L & M Grocery Store'},
#  {'address': '4508 44th St Sunnyside NY 11104',
#   'category': 'Grocery Store / Supermarket',
#   'distance': 7940,
#   'location': [40.745167, -73.92193],
#   'name': 'Taiyo Foods Japanese Grocery Store'},
#  {'address': '4510 Fort Hamilton Pkwy Brooklyn NY 11219',
#   'category': 'Grocery Store / Supermarket',
#   'distance': 8111,
#   'location': [40.640259, -73.99532099999999],
#   'name': 'Weinstein Grocery Store'}]

# %%
# Making Connection
myclient = MongoClient("mongodb://localhost:27017/") 
# database
myclient.drop_database('NYC')
db = myclient["NYC"]

# Created or Switched to collection 

Collection0 = db["hotel_data"]
Collection1 = db["restaurant_data"]
Collection2 = db["shopping_data"]
Collection3 = db["museums_data"]
Collection4 = db["groceries_data"]

# Loading or Opening the json file      
# Inserting the loaded data in the Collection
# if JSON contains data more than one entry
# insert_many is used else inser_one is used
if isinstance(hotels, list):
    Collection0.insert_many(hotels) 
    print('Created Collection 1 of 5')
else:
    Collection0.insert_one(hotels)
if isinstance(restaurants, list):
    Collection1.insert_many(restaurants)
    print('Created Collection 2 of 5')
else:
    Collection1.insert_one(restaurants)
if isinstance(shopping, list):
    Collection2.insert_many(shopping)
    print('Created Collection 3 of 5')
else:
    Collection2.insert_one(shopping)
if isinstance(museums, list):
    Collection3.insert_many(museums)
    print('Created Collection 4 of 5')
else:
    Collection3.insert_one(museums)
if isinstance(groceries, list):
    Collection4.insert_many(groceries)
    print('Created Collection 5 of 5')
else:
    Collection4.insert_one(groceries)
# Out:
# Created Collection 1 of 5
# Created Collection 2 of 5
# Created Collection 3 of 5
# Created Collection 4 of 5
# Created Collection 5 of 5
