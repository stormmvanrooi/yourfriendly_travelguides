# %%
import requests
from pprint import pprint
import pandas as pd
import json
from pandas import json_normalize 
from jsonmerge import merge

# %%
url = "https://travel-advisor.p.rapidapi.com/locations/search"

querystring1 = {"query":"New York City","limit":"30","offset":"0","latitude" :"40.7128", "longitude" :"-74.006","units":"mi","location_id":"1","currency":"USD","sort":"relevance","lang":"en_US"}
querystring2 = {"query":"New York City","limit":"30","offset":"31","latitude" :"40.7128", "longitude" :"-74.006","units":"mi","location_id":"1","currency":"USD","sort":"relevance","lang":"en_US"}
querystring3 = {"query":"New York City","limit":"30","offset":"61","latitude" :"40.7128", "longitude" :"-74.006","units":"mi","location_id":"1","currency":"USD","sort":"relevance","lang":"en_US"}
querystring4 = {"query":"New York City","limit":"30","offset":"91","latitude" :"40.7128", "longitude" :"-74.006","units":"mi","location_id":"1","currency":"USD","sort":"relevance","lang":"en_US"}
querystring5 = {"query":"New York City","limit":"30","offset":"121","latitude" :"40.7128", "longitude" :"-74.006","units":"mi","location_id":"1","currency":"USD","sort":"relevance","lang":"en_US"}
querystring6 = {"query":"New York City","limit":"30","offset":"151","latitude" :"40.7128", "longitude" :"-74.006","units":"mi","location_id":"1","currency":"USD","sort":"relevance","lang":"en_US"}
querystring7 = {"query":"New York City","limit":"30","offset":"181","latitude" :"40.7128", "longitude" :"-74.006","units":"mi","location_id":"1","currency":"USD","sort":"relevance","lang":"en_US"}
querystring8 = {"query":"New York City","limit":"30","offset":"211","latitude" :"40.7128", "longitude" :"-74.006","units":"mi","location_id":"1","currency":"USD","sort":"relevance","lang":"en_US"}
querystring9 = {"query":"New York City","limit":"30","offset":"241","latitude" :"40.7128", "longitude" :"-74.006","units":"mi","location_id":"1","currency":"USD","sort":"relevance","lang":"en_US"}
querystring10 = {"query":"New York City","limit":"30","offset":"271","latitude" :"40.7128", "longitude" :"-74.006","units":"mi","location_id":"1","currency":"USD","sort":"relevance","lang":"en_US"}
querystring11 = {"query":"New York City","limit":"30","offset":"300","latitude" :"40.7128", "longitude" :"-74.006","units":"mi","location_id":"1","currency":"USD","sort":"relevance","lang":"en_US"}
querystring12 = {"query":"New York City","limit":"30","offset":"300","latitude" :"40.7128", "longitude" :"-74.006","units":"mi","location_id":"1","currency":"USD","sort":"relevance","lang":"en_US"}


headers = {
    'x-rapidapi-host': "travel-advisor.p.rapidapi.com",
    'x-rapidapi-key': "7d25926839mshc4ae67dc5017059p11efe9jsnfbc9b4d3827e"
    }

response1 = requests.request("GET", url, headers=headers, params=querystring1)
response2 = requests.request("GET", url, headers=headers, params=querystring2)
response3 = requests.request("GET", url, headers=headers, params=querystring3)
response4 = requests.request("GET", url, headers=headers, params=querystring4)
response5 = requests.request("GET", url, headers=headers, params=querystring5)
response6 = requests.request("GET", url, headers=headers, params=querystring6)
response7 = requests.request("GET", url, headers=headers, params=querystring7)
response8 = requests.request("GET", url, headers=headers, params=querystring8)
response9 = requests.request("GET", url, headers=headers, params=querystring9)
response10 = requests.request("GET", url, headers=headers, params=querystring10)
response11 = requests.request("GET", url, headers=headers, params=querystring11)
response12 = requests.request("GET", url, headers=headers, params=querystring12)

#parsed = str(js.loads(response))
#print(js.dumps(parsed, indent=4, sort_keys=True))
#print(response.json())
# Pretty print JSON file
#json_formatted_atr = js.dumps(response, indent=4)
#print(json_formatted_atr.pretify())jsonjsonifysome_json=response.json()
#jsonify(response)json_object = json.loads(response)

pprint(response1.json())#parsed = str(js.loads(response))
# Out:
# {'data': [{'is_top_result': True,
#            'result_object': {'ancestors': [{'abbrv': 'NY',
#                                             'location_id': '28953',
#                                             'name': 'New York',
#                                             'subcategory': [{'key': 'state',
#                                                              'name': 'State'}]},
#                                            {'abbrv': None,
#                                             'location_id': '191',
#                                             'name': 'United States',
#                                             'subcategory': [{'key': 'country',
#                                                              'name': 'Country'}]}],
#                              'awards': [{'award_type': "Traveler's Choice",
#                                          'categories': ['Popular Destinations'],
# ...

# %%
pprint(response2.json())
# Out:
# {'data': [{'result_object': {'address': '6 W 33rd St, New York City, NY '
#                                         '10001-3321',
#                              'address_obj': {'city': 'New York City',
#                                              'country': 'United States',
#                                              'postalcode': '10001-3321',
#                                              'state': 'NY',
#                                              'street1': '6 W 33rd St',
#                                              'street2': ''},
#                              'ancestors': [{'abbrv': None,
#                                             'location_id': '60763',
#                                             'name': 'New York City',
#                                             'subcategory': [{'key': 'city',
#                                                              'name': 'City'}]},
#                                            {'abbrv': 'NY',
# ...

# %%
pprint(response3.json())
# Out:
# {'data': [{'result_object': {'address': '1830 Whitestone Expy, Whitestone, NY '
#                                         '11357-3061',
#                              'address_obj': {'city': 'Whitestone',
#                                              'country': 'United States',
#                                              'postalcode': '11357-3061',
#                                              'state': 'NY',
#                                              'street1': '1830 Whitestone Expy',
#                                              'street2': ''},
#                              'amenities': [],
#                              'ancestors': [{'abbrv': None,
#                                             'location_id': '48887',
#                                             'name': 'Whitestone',
#                                             'subcategory': [{'key': 'city',
#                                                              'name': 'City'}]},
# ...

# %%
hotel_array = []

for i in response1.json()['data']:
          hotel_array.append(i['result_object'])

# %%
pprint(response1.json()['data']['result_object'][])
# Out:
# [{'result_object': {'ancestors': [{'abbrv': 'NY',
#                                    'location_id': '28953',
#                                    'name': 'New York',
#                                    'subcategory': [{'key': 'state',
#                                                     'name': 'State'}]},
#                                   {'abbrv': None,
#                                    'location_id': '191',
#                                    'name': 'United States',
#                                    'subcategory': [{'key': 'country',
#                                                     'name': 'Country'}]}],
#                     'awards': [{'award_type': "Traveler's Choice",
#                                 'categories': ['Popular Destinations'],
#                                 'display_name': "Travelers' Choice 2021",
#                                 'images': {'large': 'https://www.tripadvisor.com/img2/awards/TC_2014_downloadable_L_TM.jpg',
# ...

# %%
[response1.json()['data'][1]['result_object']['name']]
# Out:
# ['Go City: New York Explorer Pass - Choose 2, 3, 4, 5, 6, 7 or 10 attractions']

# %%
for i in response1.json()['data']:
    if i['result_type']== 'things_to_do':
          print (i['result_object']['name'])
# Out:
# New York City Subway
# New York City Tour Hub
# New York City Center
# New York City Hall
# New York City Ballet
# New York City Fire Museum

# %%
for i in response1.json()['data']:
    if i['result_type']== 'lodging':
          print (i['result_object']['name'])
# Out:
# Arthouse Hotel New York City
# Distrikt Hotel New York City
# Heritage Hotel New York City
# The Ludlow New York City
# HI New York City Hostel
# The Hotel @ New York City
# Hyatt Place New York City/Times Square
# Candlewood Suites New York City- Times Square
# TRYP New York City Times Square South
# Double Tree by Hilton Hotel Metropolitan New York City
# Marriott Vacation Club Pulse, New York City
# Hyatt Place Long Island City/New York City
# Club Quarters Hotel, New York City, World Trade Center
# DoubleTree by Hilton Hotel New York City Chelsea
# Holiday Inn New York City - Times Square, an IHG hotel
# Holiday Inn Express New York City - Chelsea, an IHG hotel
# The Bernic Hotel New York City, Tapestry Collection by Hilton
# Holiday Inn Express New York City Times Square, an IHG hotel
# The Lexington Hotel, Autograph Collection
# Holiday Inn New York City - Wall Street, an IHG hotel
# The Chatwal A Luxury Collection Hotel, New York City
# ...

# %%
for i in response2.json()['data']:
    if i['result_type']== 'restaurants':
          print (i['result_object']['name'])
# Out:
# Legends New York City
# New York City Pizza
# Camarada Camarao - New York City Center
# New York City Pizza
# New York City Pizza
# New York City Pizza

# %%
for i in response2.json()['data']:
    if i['result_type']== 'activities':
          print (i['result_object']['name'])
# Out:
# New York City at Night Bus Tour
# Private Custom New York City Tour by SUV
# New York City Skyline Tour by Night with Local Guide
# New York City Landmarks Circle Line Cruise

# %%
for i in response2.json()['data']:
    if i['result_type']== 'attractions':
          print (i['result_object']['name'])

# %%
df_ny1 = pd.DataFrame((response1.json()['data']))

ny1
# Out:
#      result_type                                      result_object  scope  \
# 0           geos  {'location_id': '60763', 'name': 'New York Cit...  local
# 1     activities  {'location_id': '12181676', 'name': 'Go City: ...  local
# 2           geos  {'location_id': '28953', 'name': 'New York', '...  local
# 3   things_to_do  {'location_id': '105127', 'name': 'Central Par...  local
# 4   things_to_do  {'location_id': '104365', 'name': 'Empire Stat...  local
# 5           geos  {'location_id': '186346', 'name': 'York', 'lat...  local
# 6   things_to_do  {'location_id': '1906019', 'name': 'City Sight...  local
# 7        lodging  {'location_id': '91904', 'name': 'New York - N...  local
# 8     activities  {'location_id': '12549961', 'name': 'The New Y...  local
# 9     activities  {'location_id': '11450630', 'name': 'Big Bus N...  local
# 10    activities  {'location_id': '12275490', 'name': 'The New Y...  local
# ...

# %%
df_ny2 = pd.DataFrame((response2.json()['data']))

df_ny2
# Out:
#      result_type                                      result_object  \
# 0    restaurants  {'location_id': '1367962', 'name': 'Legends Ne...
# 1   things_to_do  {'location_id': '1750636', 'name': 'New York C...
# 2   things_to_do  {'location_id': '7184934', 'name': 'New York C...
# 3   things_to_do  {'location_id': '4005106', 'name': 'Helicopter...
# 4    restaurants  {'location_id': '5007813', 'name': 'New York C...
# 5     activities  {'location_id': '11455175', 'name': 'New York ...
# 6        lodging  {'location_id': '1465008', 'name': 'Holiday In...
# 7    restaurants  {'location_id': '10264489', 'name': 'Camarada ...
# 8   things_to_do  {'location_id': '18895596', 'name': 'The Escap...
# 9        lodging  {'location_id': '99447', 'name': 'La Quinta In...
# 10  things_to_do  {'location_id': '12116585', 'name': 'New York ...
# 11   restaurants  {'location_id': '4789387', 'name': 'New York C...
# 12       lodging  {'location_id': '1237128', 'name': 'Hotel Hayd...
# ...

# %%
df_ny3 = pd.DataFrame((response3.json()['data']))

df_ny3
# Out:
#      result_type                                      result_object  \
# 0        lodging  {'location_id': '277897', 'name': 'Extended St...
# 1     activities  {'location_id': '11450014', 'name': 'Washingto...
# 2   things_to_do  {'location_id': '14767136', 'name': 'Attractio...
# 3     activities  {'location_id': '11479184', 'name': 'New York ...
# 4        lodging  {'location_id': '124219', 'name': 'Extended St...
# 5     activities  {'location_id': '12005605', 'name': 'THE RIDE:...
# 6     activities  {'location_id': '11449825', 'name': 'New York ...
# 7     activities  {'location_id': '13286563', 'name': 'Niagara F...
# 8   things_to_do  {'location_id': '7094382', 'name': 'New York C...
# 9   things_to_do  {'location_id': '6513393', 'name': 'UCI Cinema...
# 10    activities  {'location_id': '11455439', 'name': 'Guided Bi...
# 11       lodging  {'location_id': '2095793', 'name': 'Deerpark /...
# 12  things_to_do  {'location_id': '13835845', 'name': 'New York ...
# ...

# %%
df_ny4 = pd.DataFrame((response4.json()['data']))

df_ny4
# Out:
#      result_type                                      result_object  \
# 0   things_to_do  {'location_id': '1634533', 'name': 'CV New Yor...
# 1    restaurants  {'location_id': '3468459', 'name': 'New York C...
# 2     activities  {'location_id': '13819142', 'name': 'Niagara F...
# 3   things_to_do  {'location_id': '2435546', 'name': 'Baja Bikes...
# 4   things_to_do  {'location_id': '8820311', 'name': 'New York C...
# 5     activities  {'location_id': '11452285', 'name': 'New York ...
# 6   things_to_do  {'location_id': '3518759', 'name': 'Doug Fox's...
# 7   things_to_do  {'location_id': '19235475', 'name': 'New York ...
# 8     activities  {'location_id': '11452282', 'name': 'Guided Ne...
# 9        lodging  {'location_id': '126260', 'name': 'Lotte New Y...
# 10  things_to_do  {'location_id': '2285766', 'name': 'National A...
# 11    activities  {'location_id': '11450020', 'name': 'Philadelp...
# 12   restaurants  {'location_id': '4706014', 'name': 'New York C...
# ...

# %%
df_ny5 = pd.DataFrame((response5.json()['data']))

df_ny5
# Out:
#          result_type                                      result_object  \
# 0        restaurants  {'location_id': '4502935', 'name': 'New York C...
# 1         activities  {'location_id': '12942421', 'name': 'New York ...
# 2         activities  {'location_id': '11450011', 'name': 'Boston Fr...
# 3   vacation_rentals  {'location_id': '3419713', 'name': 'New York C...
# 4        restaurants  {'location_id': '417394', 'name': 'New York Ci...
# 5        restaurants  {'location_id': '8373966', 'name': 'New York C...
# 6         activities  {'location_id': '11448548', 'name': 'New York ...
# 7        restaurants  {'location_id': '18720810', 'name': 'Koku New ...
# 8         activities  {'location_id': '11481635', 'name': 'Private N...
# 9         activities  {'location_id': '11472311', 'name': 'New York ...
# 10        activities  {'location_id': '15135724', 'name': 'New York-...
# 11        activities  {'location_id': '11483930', 'name': 'Hasidic W...
# ...

# %%
df_ny6 = pd.DataFrame((response6.json()['data']))

df_ny6
# Out:
#      result_type                                      result_object  scope  \
# 0     activities  {'location_id': '11469628', 'name': 'Bubbles a...  local
# 1     activities  {'location_id': '12932156', 'name': 'Cupcake W...  local
# 2   things_to_do  {'location_id': '10843854', 'name': 'First Chi...  local
# 3        lodging  {'location_id': '19728959', 'name': 'Private B...  local
# 4   things_to_do  {'location_id': '7898222', 'name': 'New York C...  local
# 5   things_to_do  {'location_id': '1837943', 'name': 'German/Eng...  local
# 6     activities  {'location_id': '14145484', 'name': 'New York ...  local
# 7    restaurants  {'location_id': '8820570', 'name': 'Balada Mix...  local
# 8   things_to_do  {'location_id': '8536239', 'name': 'New York C...  local
# 9   things_to_do  {'location_id': '3454077', 'name': 'Walking To...  local
# 10    activities  {'location_id': '12566358', 'name': 'Private N...  local
# ...

# %%
df_ny7 = pd.DataFrame((response7.json()['data']))

df_ny7
# Out:
#      result_type                                      result_object  scope  \
# 0     activities  {'location_id': '11483470', 'name': 'Private N...  local
# 1     activities  {'location_id': '15180422', 'name': 'New York ...  local
# 2     activities  {'location_id': '12961505', 'name': 'Full-Day ...  local
# 3    restaurants  {'location_id': '4600795', 'name': 'New York C...  local
# 4     activities  {'location_id': '12643565', 'name': 'New York ...  local
# 5    restaurants  {'location_id': '750145', 'name': 'New York Ci...  local
# 6     activities  {'location_id': '11464545', 'name': 'New York ...  local
# 7     activities  {'location_id': '12470872', 'name': 'New York ...  local
# 8        lodging  {'location_id': '18856064', 'name': 'New York ...  local
# 9        lodging  {'location_id': '14920907', 'name': 'Mr. C Sea...  local
# 10    activities  {'location_id': '11933471', 'name': 'New York ...  local
# ...

# %%
with open("response1.json", "w") as outfile:
    json.dump(response1, outfile)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-120-3ad8dabbeb48> in <module>
#       1 with open("response1.json", "w") as outfile:
# ----> 2     json.dump(response1, outfile)
#
# ~/opt/anaconda3/lib/python3.8/json/__init__.py in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     177     # could accelerate with writelines in some versions of Python, at
#     178     # a debuggability cost
# --> 179     for chunk in iterable:
#     180         fp.write(chunk)
#     181
#
# ~/opt/anaconda3/lib/python3.8/json/encoder.py in _iterencode(o, _current_indent_level)
#     436                     raise ValueError("Circular reference detected")
#     437                 markers[markerid] = o
# --> 438             o = _default(o)
#     439             yield from _iterencode(o, _current_indent_level)
# ...

# %%
result = merge(response1.json(),response2.json(),response3.json())
result2 = merge(response4.json(),response5.json(),response6.json())
result3 = merge(response7.json(),response8.json(),response9.json())
result4 = merge(response10.json(), response10.json(),response10.json())

# %%
with open("result", "w") as outfile:
    json.dump(result, outfile)

# %%
with open("result2", "w") as outfile:
    json.dump(result2, outfile)

# %%
with open("result3", "w") as outfile:
    json.dump(result3, outfile)

# %%
with open("result4", "w") as outfile:
    json.dump(result4, outfile)
